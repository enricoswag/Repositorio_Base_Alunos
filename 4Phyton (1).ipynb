# %% [markdown]
# ## operadores relacionais

# %% [markdown]
# *  > maior
# *  >= maior
# *  < menor
# *  <= menor igual
# *  != diferente
# *  == igual

# %%
10 > 20

# %%
10 < 20

# %%
5+1 != 6

# %% [markdown]
# 3+1 >=4

# %%
nome_aluno = "barbara"
nome_professora = "arroz"

# %%
10 != 10

# %% [markdown]
# ## Operadores Logicos

# %% [markdown]
# *   AND(e)
# *   OR(ou)
# *   NOT(negaçao)

# %%
(10>20) and (20>30)

# %% [markdown]
# #and
#
# true + true = true
# true+ false = false
# false + true = false
# false + false = false

# %%
(10>20) and (20>30) # false + false = false

# %%
(10<20) and (20<30) # true + true = true

# %% [markdown]
# #or
#
# true + true = true
# true + false = true
# false + true = false
# flase + false = false

# %%
(1 < 2) or (3 < 6)

# %%
"joao" == "joao" and "maria" != "maria"

# %% [markdown]
# # Not

# %% [markdown]
# #not True = false
# #not false = True

# %%
not True

# %%
not False
